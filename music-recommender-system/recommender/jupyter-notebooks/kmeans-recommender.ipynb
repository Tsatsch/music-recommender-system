# %%
import os ,sys
import json
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial.distance import cdist
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV 
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.ensemble import BalancedRandomForestClassifier
from operator import itemgetter
import copy
import numpy as np

from sklearn.metrics import silhouette_score
import joblib
import plotly.express as px 
 
from bs4 import BeautifulSoup

# %%
# !pip3 install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spotipy in /usr/local/lib/python3.7/dist-packages (2.19.0)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (2.27.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)

# %%
# !pip3 install psycopg2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.7/dist-packages (2.7.6.1)

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import psycopg2
scope='playlist-modify-public'
client_id=''
client_secret=''
redirect_uri='http://localhost:8081/callback'
username=''
token=SpotifyOAuth(client_id=client_id,client_secret=client_secret,redirect_uri=redirect_uri,scope=scope,username=username)
sp = spotipy.Spotify(auth_manager=token)
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ## Get data from the database

# %%
conn = psycopg2.connect(
            host="db-postgresql-nyc3-43851-do-user-9901141-0.b.db.ondigitalocean.com",
            dbname="",
            port="",
            user="",
            password="")
cur = conn.cursor()
cur.execute('SELECT * FROM spotify;')
res = cur.fetchall()

# %%
# The order of the columns
keys=["danceability",
"energy",
"loudness",
"speechiness",
"acousticness",
"instrumentalness",
"liveness",
"valence",

]   #"duration_ms""time_signature","key""mode","tempo"

# %%
cd /content/drive/MyDrive/CS470
# Out:
# /content/drive/MyDrive/CS470

# %% [markdown]
# ## Get user's playlist

# %%
user_playlist=pd.read_csv('Nishant2500.csv')
demo=user_playlist[:10]

# %% [markdown]
# ### Alterative: Enter song names manually
# The function below allows you to enter multiple song names ,until you enter "quit" to end this session.
#
# Return will be same format as **preprocess_playlist_1**

# %%
def input_a_song():  
  #test demo  by manually entering songs
  list_of_songs=[]#store songname
  list_of_uris=[]#store uris for songs
  artist_name=[]
  popularity=[]
  user_input=input("Enter the song: ")
  while user_input!="quit":
      result=sp.search(q=user_input,type='track')
      #print(json.dumps(result['tracks']['items'][0]["name"],sort_keys=4,indent=4))
      #print(result['tracks']['items'][0]["name"])
      list_of_songs.append([{"Song_name":user_input}])
      list_of_uris.append(result['tracks']['items'][0]['uri']) #get the uri of the track(song)
      artist_name.append({"Artist":result['tracks']['items'][0]["artists"][0]["name"]})#get the artist_name
      popularity.append({"popularity":result['tracks']['items'][0]['popularity']})#get the popularity of the song
      user_input=input("Enter the song:")
  #To extract the uri by removing 'spotify:track:'
  uri_of_playlist="".join(list_of_uris)
  uri_of_playlist=uri_of_playlist.split("spotify:track:")
  uri_of_playlist.pop(0)
  #Get all the features of the song
  Features=sp.audio_features(uri_of_playlist)
  #Append all the features to the playlist
  l=len(list_of_songs)
  for i in range(l):
      list_of_songs[i][0].update(artist_name[i])
      list_of_songs[i][0].update(popularity[i])
      list_of_songs[i][0].update(Features[i])
      del list_of_songs[i][0]['type']
      del list_of_songs[i][0]['id']
      del list_of_songs[i][0]['uri']
      del list_of_songs[i][0]['track_href']
      del list_of_songs[i][0]['analysis_url']
  return list_of_songs,uri_of_playlist

# %% [markdown]
# This below function helps you to convert a csv playlist (with only uri) convert into a list of song data

# %%
def preprocess_playlist_1(playlist): #playlist here is csv with uri
    list_of_songs=[]#store songname
    list_of_uris=[]#store uris for songs
    artist_name=[]    
    popularity=[]
    limit=100     #maxmum 100 at once
    l=len(playlist) #amount of songs
    limitcount=int(l/limit)# (#songs) /limit
    songleft=0
    for i in range(l):
       # list_of_uris.append(result['tracks']['items'][0]['uri']) #get the uri of the track(song)
        list_of_uris.append(playlist['uri'][i])
    #To extract the uri by removing 'spotify:track:'
    uri_of_playlist="".join(list_of_uris)
    uri_of_playlist=uri_of_playlist.split("spotify:track:")
    uri_of_playlist.pop(0) 
    #Get all the features of the song    
    for i in range(l):    
        result=sp.track(uri_of_playlist[i]) 
        list_of_songs.append([{"Song_name":result["name"]}])
        artist_name.append({"Artist":result["artists"][0]["name"]})#get the artist_name
        popularity.append({"popularity":result['popularity']})#get the popularity of the song
    for j in range(limitcount+2):
        songleft=l-j*limit  
        if songleft > limit:
            Features=sp.audio_features(uri_of_playlist[j*limit:j*limit+limit]) 
            for i in range(limit):
                list_of_songs[j*limit+i][0].update(artist_name[i])
                list_of_songs[j*limit+i][0].update(popularity[i])
                list_of_songs[j*limit+i][0].update(Features[i])
                del list_of_songs[j*limit+i][0]['type']
                del list_of_songs[j*limit+i][0]['id']
                del list_of_songs[j*limit+i][0]['uri']
                del list_of_songs[j*limit+i][0]['track_href']
                del list_of_songs[j*limit+i][0]['analysis_url']
        elif (songleft <=limit and songleft >0):
            Features=sp.audio_features(uri_of_playlist[j*limit:j*limit+songleft])
            for i in range(songleft):
                list_of_songs[j*limit+i][0].update(artist_name[i])
                list_of_songs[j*limit+i][0].update(popularity[i])
                list_of_songs[j*limit+i][0].update(Features[i])
                del list_of_songs[j*limit+i][0]['type']
                del list_of_songs[j*limit+i][0]['id']
                del list_of_songs[j*limit+i][0]['uri']
                del list_of_songs[j*limit+i][0]['track_href']
                del list_of_songs[j*limit+i][0]['analysis_url']
        else:
            return list_of_songs,uri_of_playlist

# %% [markdown]
# the function helps you to convert a playlist into a numpy array
#
# **Note: the input must be : result,uri=preprocess_playlist_1(user_playlist), put result into the below function**

# %%
def playlist_to_normal_array(result): #convert playlist to numpy array without preprocessing
  song_matrix=[]
  l = len(result)
  for j in range(l):
    arr=[]
    for i in range(8):
      arr.append(result[j][0][keys[i]])
    song_matrix.append(np.array(arr))
  return song_matrix

# %% [markdown]
# The function below helps you to convert a database into a numpy array
#
# **Note: the input must be :  res = cursor.fetchall(), put res  into the below function**

# %%
def db_to_normal_array(result): # convert databse to numpy arrary withou preprocessing
  l=len(result)
  train_X=[]
  for i in range(l):    
    song_matrix = np.array(list(res[i][1:9]))
    train_X.append(song_matrix)
  return train_X

# %% [markdown]
# The function below helps you to get preprocessed input playlist data with standardscaler()
#
# **Note**: If you want to use Kmeans model and RF model in your recommender, you need to use this function
#
# #input e.g.
# result,uri =  preprocess_playlist_1
#
# res = cursor.fetchall()
#
# get_std_playlist(result,res)

# %%
def get_std_playlist(result,db):  # get standardscaler processed user playlist
 
  db_tmp=db_to_normal_array(db)
  ############################################### check if the uri are in db , if not ,then add the uri to the db
  index=[]
  flag=0
  for i in range(len(uri)):
    for item in db:
      
      if uri[i] == item[0]:
        flag=1
        index.append(db.index(item))
        break;
    if flag == 0:  #not found in db
      db_tmp.append(playlist_to_normal_array(result)[i])
      index.append(len(db_tmp)-1)
    if flag ==1 : flag=0
   
 
  #############################################   
  scaler = StandardScaler() 
  scaled_features = scaler.fit_transform(db_tmp)
  ############################################# get scaled playlist
  test_X=[]
  for item in index:
    test_X.append(scaled_features[item])
  test_X=np.array(test_X) 
  ############################################
 
  return test_X

# %% [markdown]
# ## Below is an code snippet for applying the Kmeans and RF

# %%
result,uri=preprocess_playlist_1(user_playlist) # user_playlist is a csv
songs=get_std_playlist(result,res) # song = preprocessed input playlist with standarscaler
test_X=[]
######################## Feature selection : select feature from 3 to 5  which are speechiness,acousticness,and instrumentalness
for i in range(len(result)):
    test_X.append(songs[i][3:6])

pre_y=RFmodel.predict(test_X) # pre_y are predicted lables for input playlist

# %% [markdown]
# Please use standardscaler() as the preprocessing method since our Kmeans and RF are basedon standardscaler()
#
# Note: You need to ensure the input song exsit in the database,if not,append the input songs into the database(or tuple) , and do standardscaler() to the database. And then retrieve the input playlist from database so you can do KNN.
#
# If you do seperately do standardscaler() to input playlist and database, the recommending will be shitty.

# %%
def recommender(playlist,db):
  list_of_uri=[]
  list_of_songs=[]
  l=len(playlist)
  result,uri=preprocess_playlist_1(playlist)
  test_X=normalize(playlist_to_normal_array(result)) #Normalization 
  norm_db=normalize(db_to_normal_array(db))     #Normalization
 
  ##################################################### clustering
  # model=joblib.load("K6Norm.pkl")  # K = 6, features used: 0~8  ,Score = 0.26
  # y_pl=model.predict(test_X)
  # y_db=model.predict(norm_db)

   
  ###############################     K = 9 ,feature used: 345 , score = 0.46
  model = joblib.load("9Norm345.pkl")
  temp=[0]*len(db) 
  tmp=[0]*len(result)
  for i in range(len(db)):
    temp[i]=norm_db[i][3:6]
  for i in range(len(result)):
    tmp[i]=test_X[i][3:6]
  y_pl=model.predict(tmp)
  y_db=model.predict(temp)
  ################################
  ####################################################
  

  for i in range(l):
    distances = cdist(test_X[i].reshape(1,-1),norm_db,'cosine') #calculating Euclidean distance
    index = list(np.argsort(distances)[:, :10][0])

    # distances =  cosine_similarity(test_X[i].reshape(1,-1),norm_db) #Calculating Cosine similarity
    # index = list(np.argsort(-distances)[:, :10][0])  
   
    for num in index:
      if uri[i] != db[num][0] and y_pl[i] ==y_db[num]: 
        list_of_uri.append(db[num][0])
          
          
  for i in range(len(list_of_uri)):    
          result=sp.track(list_of_uri[i]) 
          list_of_songs.append([list_of_uri[i]])
          list_of_songs[i].append(result["name"])
          list_of_songs[i].append(result["artists"][0]["name"])
          list_of_songs[i].append(result['popularity'])

 
  for i in range(len(list_of_songs))[::-1]:
    if list_of_songs[i][3] < 20:
      list_of_songs.pop(i)        
  out=pd.DataFrame(list_of_songs,columns=[ 'URI','Song','Artist' ,'Popularity'])
  out.set_index('URI', inplace=True)
  return out.sort_values(by=['Popularity'],ascending=False)
 
  
   
recommender(demo,res)
# Out:
#                                                                      Song  \
# URI
# 4JiEyzf0Md7KEFFGWDDdCr                          Knockin' On Heaven's Door
# 4S7YHmlWwfwArgd8LfSPud                                                L$D
# 0lIoY4ZQsdn5QzhraM9o9u                                  Because the Night
# 3GhsBdS9ulPK3KCdwHRPhG                      Nothing's Gonna Hurt You Baby
# 0XOnMqLQDO89iAg7dWWwnG                                      pete davidson
# 0LO7f7ZJg871B8hLTRzrfB                                              Julia
# 3xvcFlh6hHqxyiAFkqpsjZ                                 Always and Forever
# 3mBCTEzhxcv6jLaxXoOvWs                                Moondust - Stripped
# 0Qbc2tyiSclb6vYvOxvebM                                          Warm Love
# 3420nZEhm99I1bLc6Yx4XH                                     Lonely Weekend
# 6Rqe6ghJ6t9SlQ2pRrt5tI                     Till Dawn (Here Comes The Sun)
# 4snBTILMGyRKErKygwoDkE                                 New York, New York
# 1UMXtudajhlocMzXVSngDU                                          The Trial
# 7sDzAu7alAL1hWvL86tSGB  Sweater Weather - Spotify Sessions Curated by ...
# 3mtUR8aNUoMblqX49YzVF3                                  Life Is Beautiful
# 0L2ljTJonS78v8qSlpxM0d                              High On A Rocky Ledge
# 36lV4io8Gc69fDinNaazAg                                 The Weight of Lies
# 05JVdHDpvHTqHnRmmzi9YM                              In The Silence - Demo
# 3gAI3aE3aLJblp25UEH6zs                                  Would You Believe
# 5q39B87pigCYl80puT66OK                                           The Walk
# 1UR7rr3oZgM8TeuWJfLa64                                      Tennessee Jed
# 0JrodaFVB3keEja7U1PabP                                          Tied Down
# 2lnuEN52eBlzoU648T1DUV                           Un-Thinkable - I'm Ready
# 0sr84SDJ9VN4EB7p2mWGur                                  Get over Yourself
# 0bsX0VslnmcBoPYQFNdxqX       This I Believe (The Creed) - Radio Edit/Live
# 0950zBhDfpTlPmANus8lIq                            Where I Go When I Drink
# 0L3di3gB5KlamEABLJK8KK                                   Your Biggest Fan
# 5jwCEcnS7IXWhD4KuunEDE                       Happy Ever After (Zero Hour)
# 3zV5iYPyZUgcaFCcPem3ZN                                 Losing My Religion
# 1HMM9fj7Wvimbx4SkWXD5A                                   I Fall To Pieces
# 6PFyNafV5oe3oR9OQ4qS2b  No Signs (From "They Fight" Original Motion Pi...
# 5aA2v6AQgFHsmZO87tiaec  Oceans (Where Feet My Fail) - Live/Acoustic Ve...
# 5rSYbDj0iOntehwhonDS1a                                That's Why I'm Here
# 1u7ATTVsQJeSv2zaxYO2ci                                       When I Drink
# 3JYWwjsqtBPQ7xQyIg6x0c                                Sink, Florida, Sink
# 4gPpDeHntIaxvJXP53QtIj                 No One Is to Blame - 2018 Remaster
# 3O5q0oFwr1d6jkDytJhxVo                        New Love (Acoustic Version)
# 6zv8my03uPj67vp5pILDX0                   Here and Now (feat. Will Reagan)
# 5aewKA6EA4WTbp89Mt6C4X                          Never Seen You Get So Low
# 2vEMZ2TGSaIQxJ6K5dvX0W                                    The Last Cowboy
# 7cxXXzT8n0YVstjvCvcsCA                               Speak to the Silence
# 2VHQP8eygtpBxYmKEqx9Oy                                         Best Times
# 1cj8UCZFcMvrPWugfljgny                                      EX - Acoustic
# 0PIQBYYUfjdo4LVAgnyWp4                                        Singularity
# 6MoB4CUkTSOGbnXvI0Tpe4                                      Back Together
# 1qBk8jyJmxeXAbbrZ1thxL                       Put That Away And Talk To Me
# 0I67c6jPoBxVkUwo02bZnD                                     History Lesson
# 1Uw444NYI7efPb6W2Uvz08                                         Gold to Me
# 3lS0DcJDzDiaqAje0LViWe                             Just Look at This Mess
# 2oZkpHnaCspSxuitY4pMsi                 This Will Be (An Everlasting Love)
# 13AlATiLj55UNdjOGICV7X                                    Song of Solomon
# 0vt0KNu6SoecopUq9sp4vS                                        Slow & Easy
# 2iFiwkAEBPtQKk8xmHFJwN                                               Leaf
# 4YGbVUdrIc6RbE6n1cl7gy                              Entre Palos y Alegría
# 7eHFxhTnarOlfVWvxrB1Cx                                    - A beginning -
# 6FXhl9p8bIYxOWEfOis5Xi                           Ain't Gonna Moan No More
#
#                                       Artist  Popularity
# URI
# 4JiEyzf0Md7KEFFGWDDdCr         Guns N' Roses          77
# 4S7YHmlWwfwArgd8LfSPud            A$AP Rocky          73
# 0lIoY4ZQsdn5QzhraM9o9u           Patti Smith          68
# 3GhsBdS9ulPK3KCdwHRPhG  Cigarettes After Sex          65
# 0XOnMqLQDO89iAg7dWWwnG         Ariana Grande          60
# 0LO7f7ZJg871B8hLTRzrfB               Mt. Joy          59
# 3xvcFlh6hHqxyiAFkqpsjZ       Luther Vandross          55
# 3mBCTEzhxcv6jLaxXoOvWs          Jaymes Young          54
# 0Qbc2tyiSclb6vYvOxvebM          Van Morrison          53
# 3420nZEhm99I1bLc6Yx4XH       Kacey Musgraves          53
# 6Rqe6ghJ6t9SlQ2pRrt5tI            The Weeknd          52
# 4snBTILMGyRKErKygwoDkE            Ryan Adams          50
# 1UMXtudajhlocMzXVSngDU            Pink Floyd          50
# 7sDzAu7alAL1hWvL86tSGB     The Neighbourhood          49
# 3mtUR8aNUoMblqX49YzVF3              Keb' Mo'          48
# 0L2ljTJonS78v8qSlpxM0d               Moondog          48
# 36lV4io8Gc69fDinNaazAg    The Avett Brothers          47
# 05JVdHDpvHTqHnRmmzi9YM             JP Cooper          46
# 3gAI3aE3aLJblp25UEH6zs               Sam Kim          45
# 5q39B87pigCYl80puT66OK          Sawyer Brown          45
# 1UR7rr3oZgM8TeuWJfLa64            Levon Helm          44
# 0JrodaFVB3keEja7U1PabP          Jaymes Young          44
# 2lnuEN52eBlzoU648T1DUV       City and Colour          43
# 0sr84SDJ9VN4EB7p2mWGur      Kelsea Ballerini          42
# 0bsX0VslnmcBoPYQFNdxqX      Hillsong Worship          42
# 0950zBhDfpTlPmANus8lIq           Chris Young          41
# 0L3di3gB5KlamEABLJK8KK     Never Shout Never          41
# 5jwCEcnS7IXWhD4KuunEDE          Foo Fighters          41
# 3zV5iYPyZUgcaFCcPem3ZN         Jacqui Naylor          41
# 1HMM9fj7Wvimbx4SkWXD5A         Jamey Johnson          40
# 6PFyNafV5oe3oR9OQ4qS2b                  ODIE          39
# 5aA2v6AQgFHsmZO87tiaec       Hillsong UNITED          39
# 5rSYbDj0iOntehwhonDS1a         Kenny Chesney          38
# 1u7ATTVsQJeSv2zaxYO2ci    The Avett Brothers          38
# 3JYWwjsqtBPQ7xQyIg6x0c           Against Me!          38
# 4gPpDeHntIaxvJXP53QtIj          Howard Jones          37
# 3O5q0oFwr1d6jkDytJhxVo        Josh Heinrichs          37
# 6zv8my03uPj67vp5pILDX0        United Pursuit          37
# 5aewKA6EA4WTbp89Mt6C4X                Aquilo          36
# 2vEMZ2TGSaIQxJ6K5dvX0W         Jamey Johnson          36
# 7cxXXzT8n0YVstjvCvcsCA           Will Reagan          36
# 2VHQP8eygtpBxYmKEqx9Oy                 SALES          35
# 1cj8UCZFcMvrPWugfljgny            Kiana Ledé          34
# 0PIQBYYUfjdo4LVAgnyWp4           Darlingside          34
# 6MoB4CUkTSOGbnXvI0Tpe4            Jill Scott          34
# 1qBk8jyJmxeXAbbrZ1thxL           James Blake          33
# 0I67c6jPoBxVkUwo02bZnD          Nicolas Jaar          33
# 1Uw444NYI7efPb6W2Uvz08           Dirty Heads          31
# 3lS0DcJDzDiaqAje0LViWe        Punch Brothers          30
# 2oZkpHnaCspSxuitY4pMsi              Dave Koz          30
# 13AlATiLj55UNdjOGICV7X          Martin Smith          29
# 0vt0KNu6SoecopUq9sp4vS        Scott H. Biram          28
# 2iFiwkAEBPtQKk8xmHFJwN          Zack Villere          25
# 4YGbVUdrIc6RbE6n1cl7gy  Cardenales Del Exito          25
# 7eHFxhTnarOlfVWvxrB1Cx           MYTH & ROID          23
# 6FXhl9p8bIYxOWEfOis5Xi          Van Morrison          20

# %%
def recommender_4(db):     # enter a song , do standarscaler preprocessing and return recommended
  l=len(db)
  list_of_uri=[]
  list_of_songs=[]
  result,uri=input_a_song() 
  test_X= get_std_playlist(result,db)
  # db_tmp=db_to_normal_array(db)
  # ############################################### check if the uri are in db , if not ,then add the uri to the db
  # index=[]
  # flag=0
  # for i in range(len(uri)):
  #   for item in db:
      
  #     if uri[i] == item[0]:
  #       flag=1
  #       index.append(db.index(item))
  #       break;
  #   if flag == 0:  #not found in db
  #     db_tmp.append(playlist_to_normal_array(result)[i])
  #     index.append(len(db_tmp)-1)
  #   if flag ==1 : flag=0
   
 
  # #############################################   
  # scaler = StandardScaler() 
  # scaled_features = scaler.fit_transform(db_tmp)
  # ############################################# get scaled playlist
  # test_X=[]
  # for item in index:
  #   test_X.append(scaled_features[item])
  # test_X=np.array(test_X) 
  # ############################################
  
  # temp=[0]*l 
  # tmp=[0]*len(result)
  
  

  # ########################################################### feature selection
  # for i in range(l):
  # #train_X[i]=np.delete(train_X[i],np.s_[0,1,2,],axis=0),
  #   temp[i]=scaled_features[i][3:6]
  # for i in range(len(result)):
  #   tmp[i]=test_X[i][3:6]  
  # ##########################################################
   
  # ################################### clustering
  # model=joblib.load("Kstd6.pkl")
  # y_pl=model.predict(tmp)
  # y_db=model.predict(temp)
  # ###################################
   
  l=len(result)
   

  scaled_features = scaler.fit_transform(db_to_normal_array(db))

  for i in range(l):
    distances = cdist(test_X[i].reshape(1,-1),scaled_features,'cosine') #calculating Euclidean distance
    index = list(np.argsort(distances)[:, :10][0])

    # distances =  cosine_similarity(test_X[i].reshape(1,-1),scaled_features) #Calculating Cosine similarity
    # index = list(np.argsort(-distances)[:, :10][0])  
   
    for num in index:
        #if uri[i] != db[num][0] and y_pl[i] ==y_db[num]: 
          list_of_uri.append(db[num][0])
          
          

  for i in range(len(list_of_uri)):    
          result=sp.track(list_of_uri[i]) 
          list_of_songs.append([list_of_uri[i]])
          list_of_songs[i].append(result["name"])
          list_of_songs[i].append(result["artists"][0]["name"])
          list_of_songs[i].append(result['popularity'])

 
  for i in range(len(list_of_songs))[::-1]:
    if list_of_songs[i][3] < 20:
      list_of_songs.pop(i)        
  out=pd.DataFrame(list_of_songs,columns=[ 'URI','Song','Artist' ,'Popularity'])
  out.set_index('URI', inplace=True)
  return out.sort_values(by=['Popularity'],ascending=False)  
recommender_4(res)

# %%
def recommender5(db):  # input songs, enter "quit" to quit. Return : recommended songs
  list_of_uri=[]
  list_of_songs=[]
  result,uri=input_a_song()
  l=len(result)
  test_X=normalize(playlist_to_normal_array(result)) #Normalization 
  norm_db=normalize(db_to_normal_array(db))     #Normalization
 


  ##################################################### clustering
  # model=joblib.load("K6Norm.pkl")  # K = 6, features used: 0~8  ,Score = 0.26
  # y_pl=model.predict(test_X)
  # y_db=model.predict(norm_db)

   
  ###############################     K = 9 ,feature used: 345 , score = 0.46
  model = joblib.load("9Norm345.pkl")
  temp=[0]*len(db) 
  tmp=[0]*len(result)
  for i in range(len(db)):
    temp[i]=norm_db[i][3:6]
  for i in range(len(result)):
    tmp[i]=test_X[i][3:6]
  y_pl=model.predict(tmp)
  y_db=model.predict(temp)
  ################################
  ####################################################


  for i in range(l):
    distances = cdist(test_X[i].reshape(1,-1),norm_db,'cosine') #calculating Euclidean distance
    index = list(np.argsort(distances)[:, :10][0])

    # distances =  cosine_similarity(test_X[i].reshape(1,-1),norm_db) #Calculating Cosine similarity
    # index = list(np.argsort(-distances)[:, :10][0])  
   
    for num in index:
      if uri[i] != db[num][0] and y_pl[i] ==y_db[num]: 
        list_of_uri.append(db[num][0])
          
          

  for i in range(len(list_of_uri)):    
          result=sp.track(list_of_uri[i]) 
          list_of_songs.append([list_of_uri[i]])
          list_of_songs[i].append(result["name"])
          list_of_songs[i].append(result["artists"][0]["name"])
          list_of_songs[i].append(result['popularity'])

 
  for i in range(len(list_of_songs))[::-1]:
    if list_of_songs[i][3] < 20:
      list_of_songs.pop(i)        
  out=pd.DataFrame(list_of_songs,columns=[ 'URI','Song','Artist' ,'Popularity'])
  out.set_index('URI', inplace=True)
  return out.sort_values(by=['Popularity'],ascending=False)
recommender5(res)
# Out:
# Enter the song: goosebumps
# Enter the song:quit
#                                                   Song         Artist  \
# URI
# 6gBFPUFcJLzWGx4lenP6h2                      goosebumps   Travis Scott
# 09IStsImFySgyp0pIQdqAc                      The Middle           Zedd
# 62FOsBpnZXEoPc1Qo9hcap               Beautiful Goodbye       Maroon 5
# 3z9xNouuYUaVLizmZdVkpR  Dawsin's Breek (feat. Jeremih)  Ty Dolla $ign
#
#                         Popularity
# URI
# 6gBFPUFcJLzWGx4lenP6h2          83
# 09IStsImFySgyp0pIQdqAc          80
# 62FOsBpnZXEoPc1Qo9hcap          50
# 3z9xNouuYUaVLizmZdVkpR          38
